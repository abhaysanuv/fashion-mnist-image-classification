# %%
pip install --upgrade tensorflow

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(optimizer=tf.compat.v1.train.AdamOptimizer(),
              loss='sparse_categorical_crossentropy', metrics='accuracy')

# %%
model.fit(train_images, train_labels, epochs=50)
# Out:
# Epoch 1/50
# 2024-02-26 17:58:01.304331: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 47040000 exceeds 10% of free system memory.
# 1875/1875 [==============================] - 3s 2ms/step - loss: 3.3059 - accuracy: 0.6943
# Epoch 2/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.7147 - accuracy: 0.7587
# Epoch 3/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5836 - accuracy: 0.8041
# Epoch 4/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5460 - accuracy: 0.8184
# Epoch 5/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5223 - accuracy: 0.8269
# Epoch 6/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5163 - accuracy: 0.8304
# Epoch 7/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5107 - accuracy: 0.8337
# Epoch 8/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4969 - accuracy: 0.8378
# ...

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=1)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5743 - accuracy: 0.8177

# %%
test_acc
# Out:
# 0.8177000284194946

# %%
import matplotlib.pyplot as plt
plt.imshow(test_images[1001])

# %%
predictions = model.predict(test_images, axis=1)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
predicted_labels = np.argmax(predictions, axis=1)

pred_df = pd.DataFrame({'Predicted Label': predicted_labels, 'Actual Label': test_labels})

pred_df
# Out:
#       Predicted Label  Actual Label
# 0                   9             9
# 1                   2             2
# 2                   1             1
# 3                   1             1
# 4                   6             6
# ...               ...           ...
# 9995                9             9
# 9996                1             1
# 9997                8             8
# 9998                1             1
# 9999                5             5
#
# [10000 rows x 2 columns]

# %%
pred_df[pred_df['Predicted Label']!=pred_df['Actual Label']]
# Out:
#       Predicted Label  Actual Label
# 6                   6             4
# 17                  2             4
# 23                  5             9
# 25                  2             4
# 29                  6             3
# ...               ...           ...
# 9972                6             2
# 9977                0             6
# 9979                0             6
# 9989                2             4
# 9991                2             6
#
# [1823 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

conf_matrix = confusion_matrix(test_labels, predicted_labels)

conf_df = pd.DataFrame(conf_matrix, index=range(10), columns=range(10))


plt.figure(figsize=(10, 8))
sns.heatmap(conf_df, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
